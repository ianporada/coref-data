# %%
import datasets

from datasets.utils.logging import disable_progress_bar
disable_progress_bar()

# %%
DATASETS = [
    ("coref-data/conll2012_indiscrim", "english_v4"),
    "coref-data/preco_indiscrim",
    "coref-data/phrase_detectives_indiscrim",
    ("coref-data/litbank_indiscrim", "split_0"),
    ("coref-data/gum_indiscrim", "ontogum"),
    "coref-data/arrau_indiscrim",
    ("coref-data/mmc_indiscrim", "mmc_en"),
]

# %%
def get_stats(example):
    sentences = example["sentences"]
    coref_chains = example["coref_chains"]

    sentence_lens = [len(s["tokens"]) for s in sentences]
    non_singleton_chains = [c for c in coref_chains if len(c) > 1]

    num_sentences = len(sentences)
    num_tokens = sum(sentence_lens)
    num_chains = len(coref_chains)
    num_ments = sum([len(c) for c in coref_chains])
    num_singletons = len([c for c in coref_chains if len(c) == 1])
    num_nonsingleton_chains = len(non_singleton_chains)
    num_nonsingleton_ments = sum([len(c) for c in non_singleton_chains])

    return {
        "num_sentences": num_sentences,
        "num_tokens": num_tokens,
        "num_chains": num_chains,
        "num_ments": num_ments,
        "num_singletons": num_singletons,
        "num_nonsingleton_chains": num_nonsingleton_chains,
        "num_nonsingleton_ments": num_nonsingleton_ments,
    }

# %%
from statistics import mean


for dataset_name in DATASETS:
    if type(dataset_name) is tuple:
        name, config = dataset_name
        dataset = datasets.load_dataset(name, config)
    else:
        dataset = datasets.load_dataset(dataset_name)

    print("\n" + "="*10)
    print(dataset_name)
    for split, data in dataset.items():
        print(split)
        print("Total examples:", len(data["id"]))

        stats = data.map(get_stats, remove_columns=data.column_names, num_proc=4)

        print("Avg num sentences:",
              mean([x["num_sentences"] for x in stats])
              )
        
        print("Avg num tokens:",
              mean([x["num_tokens"] for x in stats])
              )
        
        print("Avg num chains:",
              mean([x["num_chains"] for x in stats])
              )
        
        print("Avg num mentions:",
              mean([x["num_ments"] for x in stats])
              )
        
        print("Avg num singletons:",
              mean([x["num_singletons"] for x in stats])
              )
        
        print("Avg num non-singleton chains:",
              mean([x["num_nonsingleton_chains"] for x in stats])
              )
        
        print("Avg num non-singleton mentions:",
              mean([x["num_nonsingleton_ments"] for x in stats])
              )
            
        print("="*10)
# Out:
# ==========
# ('coref-data/conll2012_indiscrim', 'english_v4')
# train
# Total examples: 2802
# Avg num sentences: 26.833333333333332
# Avg num tokens: 463.7087794432548
# Avg num chains: 12.542112776588151
# Avg num mentions: 55.51713062098501
# Avg num singletons: 0
# Avg num non-singleton chains: 12.542112776588151
# Avg num non-singleton mentions: 55.51713062098501
# ==========
# validation
# Total examples: 343
# Avg num sentences: 27.997084548104958
# Avg num tokens: 475.52186588921285
# Avg num chains: 13.253644314868804
# Avg num mentions: 55.84839650145773
# Avg num singletons: 0
# Avg num non-singleton chains: 13.253644314868804
# Avg num non-singleton mentions: 55.84839650145773
# ==========
# test
# Total examples: 348
# Avg num sentences: 27.238505747126435
# Avg num tokens: 487.29597701149424
# Avg num chains: 13.022988505747126
# Avg num mentions: 56.793103448275865
# Avg num singletons: 0
# Avg num non-singleton chains: 13.022988505747126
# Avg num non-singleton mentions: 56.793103448275865
# ==========
#
# ==========
# coref-data/preco_indiscrim
# train
# Total examples: 36120
# Avg num sentences: 25.288676633444076
# Avg num tokens: 336.65678294573644
# Avg num chains: 65.83372093023256
# Avg num mentions: 104.82724252491694
# Avg num singletons: 54.54296788482835
# Avg num non-singleton chains: 11.290753045404209
# Avg num non-singleton mentions: 50.28427464008859
# ==========
# validation
# Total examples: 500
# Avg num sentences: 24.468
# Avg num tokens: 333.426
# Avg num chains: 65.57
# Avg num mentions: 104.014
# Avg num singletons: 54.338
# Avg num non-singleton chains: 11.232
# Avg num non-singleton mentions: 49.676
# ==========
# test
# Total examples: 500
# Avg num sentences: 25.87
# Avg num tokens: 332.382
# Avg num chains: 63.586
# Avg num mentions: 103.956
# Avg num singletons: 51.99
# Avg num non-singleton chains: 11.596
# Avg num non-singleton mentions: 51.966
# ==========
#
# ==========
# coref-data/phrase_detectives_indiscrim
# train
# Total examples: 695
# Avg num sentences: 68.75395683453237
# Avg num tokens: 1761.221582733813
# Avg num chains: 327.5136690647482
# Avg num mentions: 487.9755395683453
# Avg num singletons: 286.75827338129494
# Avg num non-singleton chains: 40.75539568345324
# Avg num non-singleton mentions: 201.21726618705037
# ==========
# validation
# Total examples: 45
# Avg num sentences: 65.28888888888889
# Avg num tokens: 1633.9555555555555
# Avg num chains: 308.3777777777778
# Avg num mentions: 444.4888888888889
# Avg num singletons: 270.3333333333333
# Avg num non-singleton chains: 38.044444444444444
# Avg num non-singleton mentions: 174.15555555555557
# ==========
# test
# Total examples: 45
# Avg num sentences: 20.57777777777778
# Avg num tokens: 529.2444444444444
# Avg num chains: 95.77777777777777
# Avg num mentions: 153.04444444444445
# Avg num singletons: 80.62222222222222
# Avg num non-singleton chains: 15.155555555555555
# Avg num non-singleton mentions: 72.42222222222222
# ==========
#
# ==========
# ('coref-data/litbank_indiscrim', 'split_0')
# train
# Total examples: 80
# Avg num sentences: 84.4375
# Avg num tokens: 2118.2
# Avg num chains: 79.3
# Avg num mentions: 290.225
# Avg num singletons: 57.9375
# Avg num non-singleton chains: 21.3625
# Avg num non-singleton mentions: 232.2875
# ==========
# validation
# Total examples: 10
# Avg num sentences: 92.7
# Avg num tokens: 2043.8
# Avg num chains: 77.6
# Avg num mentions: 305.3
# Avg num singletons: 56.3
# Avg num non-singleton chains: 21.3
# Avg num non-singleton mentions: 249
# ==========
# test
# Total examples: 10
# Avg num sentences: 88
# Avg num tokens: 2063.8
# Avg num chains: 80.7
# Avg num mentions: 283.2
# Avg num singletons: 56.5
# Avg num non-singleton chains: 24.2
# Avg num non-singleton mentions: 226.7
# ==========
#
# ==========
# ('coref-data/gum_indiscrim', 'ontogum')
# train
# Total examples: 165
# Avg num sentences: 55.96363636363636
# Avg num tokens: 973.4606060606061
# Avg num chains: 29.066666666666666
# Avg num mentions: 127.84242424242424
# Avg num singletons: 0.07878787878787878
# Avg num non-singleton chains: 28.98787878787879
# Avg num non-singleton mentions: 127.76363636363637
# ==========
# validation
# Total examples: 24
# Avg num sentences: 50.875
# Avg num tokens: 891.5416666666666
# Avg num chains: 26.625
# Avg num mentions: 120.25
# Avg num singletons: 0.125
# Avg num non-singleton chains: 26.5
# Avg num non-singleton mentions: 120.125
# ==========
# test
# Total examples: 24
# Avg num sentences: 50.041666666666664
# Avg num tokens: 906.7916666666666
# Avg num chains: 27.541666666666668
# Avg num mentions: 112.79166666666667
# Avg num singletons: 0
# Avg num non-singleton chains: 27.541666666666668
# Avg num non-singleton mentions: 112.79166666666667
# ==========
#
# ==========
# coref-data/arrau_indiscrim
# train
# Total examples: 444
# Avg num sentences: 39.75
# Avg num tokens: 615.7117117117117
# Avg num chains: 107.43243243243244
# Avg num mentions: 173.8716216216216
# Avg num singletons: 86.93018018018019
# Avg num non-singleton chains: 20.50225225225225
# Avg num non-singleton mentions: 86.94144144144144
# ==========
# validation
# Total examples: 33
# Avg num sentences: 82.6969696969697
# Avg num tokens: 950.3333333333334
# Avg num chains: 141.8181818181818
# Avg num mentions: 253.5151515151515
# Avg num singletons: 112.18181818181819
# Avg num non-singleton chains: 29.636363636363637
# Avg num non-singleton mentions: 141.33333333333334
# ==========
# test
# Total examples: 75
# Avg num sentences: 27.04
# Avg num tokens: 577.8
# Avg num chains: 107.04
# Avg num mentions: 168
# Avg num singletons: 86.22666666666667
# Avg num non-singleton chains: 20.813333333333333
# Avg num non-singleton mentions: 81.77333333333333
# ==========
#
# ==========
# ('coref-data/mmc_indiscrim', 'mmc_en')
# train
# Total examples: 955
# Avg num sentences: 19.34764397905759
# Avg num tokens: 271.1413612565445
# Avg num chains: 26.543455497382197
# Avg num mentions: 63.87015706806283
# Avg num singletons: 17.319371727748692
# Avg num non-singleton chains: 9.224083769633507
# Avg num non-singleton mentions: 46.550785340314135
# ==========
# validation
# Total examples: 134
# Avg num sentences: 19.238805970149254
# Avg num tokens: 274.14179104477614
# Avg num chains: 35.850746268656714
# Avg num mentions: 75.21641791044776
# Avg num singletons: 25.940298507462686
# Avg num non-singleton chains: 9.91044776119403
# Avg num non-singleton mentions: 49.276119402985074
# ==========
# test
# Total examples: 133
# Avg num sentences: 14.353383458646617
# Avg num tokens: 210.1654135338346
# Avg num chains: 28.63157894736842
# Avg num mentions: 59.83458646616541
# Avg num singletons: 19.69924812030075
# Avg num non-singleton chains: 8.93233082706767
# Avg num non-singleton mentions: 40.13533834586466
# ==========
